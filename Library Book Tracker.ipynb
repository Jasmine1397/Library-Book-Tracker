# %%
library = []

borrowed_books = ()

# Adding a book

def add_book():
    title = input("Enter book title:")
    author = input("Enter author name:")
    genre = input("Enter book genre:")
    publication_year = input("Enter the publication year:")
    book = f"{title} by {author}"
    if book not in library:
        library.append(book)
        print(f"{title} has been added to the collection")
    else:
        print(f"{title} is already in the collection")

# %%
# search for books

def search_book():
    keyword = input("Enter a keyword to search for a book:")
    books_found = [book for book in library if keyword.lower() in book.lower()]
    if books_found:
        print("Book found:")
        for book in books_found:
            print(book)
    else:
        print("Book not found!")

# %%
# remove the book

def remove_book():
    title = input("Enter the exact title of the book to remove: ")
    book_to_remove = next((book for book in library if title.lower() in book.lower()), None)
    if book_to_remove:
        library.remove(book_to_remove)
        print(f"'{title}' has been removed from the collection.")
    else:
        print(f"'{title}' not found in the collection.")

# %%
# display unique authors

def display_unique_authors():
    authors = {book.split('by')[1] for book in library}
    if authors:
        print("Unique Authors:")
        for author in authors:
            print(author)
    else:
        print("author not found!")

# %%
# sort books by title
def sort_books():
    library.sort()  
    print("Books sorted by title:")
    for book in library:
        print(book)

# %%
# borrow books

def borrow_book():
    title = input("Enter the title of the book you want to borrow: ")
    borrower = input("Enter the borrower's name: ")
    book_to_borrow = next((book for book in library if title.lower() in book.lower()), None)
    if book_to_borrow:
        global borrowed_books
        borrowed_books += ((book_to_borrow, borrower),)
        print(f"'{title}' has been borrowed by {borrower}.")
    else:
        print(f"'{title}' is not available in the collection.")

# %%
# show borrowed books

def display_borrowed_books():
    if borrowed_books:
        print("Borrowed Books:")
        for book, borrower in borrowed_books:
            print(f"{book} is borrowed by {borrower}")
    else:
        print(f"No books are currently borrowed")

# %%
# creating a main menu for all the function

def menu():
    while True:
        print("\nLibrary Book Tracker")
        print("1. Add a new book")
        print("2. Search for books")
        print("3. Remove a book")
        print("4. Display unique authors")
        print("5. Display books sorted by title")
        print("6. Borrow a book")
        print("7. Show borrowed books")
        print("8. Exit")
        
        choice = input("Choose an option (1-8): ")
        
        if choice == "1":
            add_book()
        elif choice == "2":
            search_book()
        elif choice == "3":
            remove_book()
        elif choice == "4":
            display_unique_authors()
        elif choice == "5":
            sort_books()
        elif choice == "6":
            borrow_book()
        elif choice == "7":
            display_borrowed_books()
        elif choice == "8":
            print("Exiting the program.")
            break  # Correct usage of 'break' inside a loop
        else:
            print("Invalid choice. Please choose a valid option.")

# %%
menu()
# Out:
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 1
# Enter book title:Days of Distraction
# Enter author name:Alexandra Chang
# Enter book genre:Contemporary Fiction, Literary Fiction
# Enter the publication year:2020
# Days of Distraction has been added to the collection
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 1
# Enter book title:The Fountainhead
# Enter author name:Ayn Rand
# Enter book genre:Fiction, Philosophy
# Enter the publication year:1943
# The Fountainhead is already in the collection
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 1
# Enter book title:White Nights
# Enter author name:Fyodor Dostoevsky
# Enter book genre:Classic, Romance
# Enter the publication year:1848
# White Nights is already in the collection
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 2
# Enter a keyword to search for a book:Days
# Book found:
# Days of Distraction by Alexandra Chang
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 3
# Enter the exact title of the book to remove: Days
# 'Days' has been removed from the collection.
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 3
# Enter the exact title of the book to remove: Days of Distraction
# 'Days of Distraction' not found in the collection.
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 4
# Unique Authors:
#  Ayn Rand
#  Fyodor Dostoevsky
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 5
# Books sorted by title:
# The Fountainhead by Ayn Rand
# White Nights by Fyodor Dostoevsky
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 6
# Enter the title of the book you want to borrow: White Nights
# Enter the borrower's name: Jasmine Khadgi
# 'White Nights' has been borrowed by Jasmine Khadgi.
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 7
# Borrowed Books:
# White Nights by Fyodor Dostoevsky is borrowed by Jasmine Khadgi
# White Nights by Fyodor Dostoevsky is borrowed by Jasmine Khadgi
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 7
# Borrowed Books:
# White Nights by Fyodor Dostoevsky is borrowed by Jasmine Khadgi
# White Nights by Fyodor Dostoevsky is borrowed by Jasmine Khadgi
#
# Library Book Tracker
# 1. Add a new book
# 2. Search for books
# 3. Remove a book
# 4. Display unique authors
# 5. Display books sorted by title
# 6. Borrow a book
# 7. Show borrowed books
# 8. Exit
# Choose an option (1-8): 8
# Exiting the program.

# %%
'''
Days of Distraction

Author: Alexandra Chang
Genre: Contemporary Fiction, Literary Fiction
Publication Year: 2020
    

The Fountainhead

Author: Ayn Rand
Genre: Fiction, Philosophy
Publication Year: 1943

White Nights

Author: Fyodor Dostoevsky
Genre: Classic, Romance
Publication Year: 1848

'''
